# %% [markdown]
# #### importing the dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# Out:
# C:\Users\Shashi Shekhar\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# #### Data collection to dataframe in pnadas

# %%
data=pd.read_csv(r"C:\Users\Shashi Shekhar\Desktop\python\Dataset for resume projects\winequality-red.csv")
data.shape
# Out:
# (1599, 12)

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# checking for missing values
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# #### Data Analysis & Visualization

# %%
#statistical figure
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#number of values of each quality
data["quality"].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
#visualization of value of each quality
sns.catplot(x="quality", data=data, kind="count");
# Out:
# C:\Users\Shashi Shekhar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.countplot(x="quality", data=data);

# %%
#volatile acidity vs quality
plt.figure(figsize=(5,5))
sns.barplot(x="quality", y="volatile acidity", data=data);

# %%
#citric acidity vs quality
plt.figure(figsize=(5,5))
sns.barplot(x="quality", y="citric acid", data=data);

# %%
#fixed acidity vs quality
plt.figure(figsize=(5,5))
sns.barplot(x="quality", y="fixed acidity", data=data);

# %%
#residual sugar vs quality
plt.figure(figsize=(5,5))
sns.barplot(x="quality", y="residual sugar", data=data);

# %%
#chlorides vs quality
plt.figure(figsize=(5,5))
sns.barplot(x="quality", y="chlorides", data=data);

# %%
#free sulfur dioxide vs quality
plt.figure(figsize=(5,5))
sns.barplot(x="quality", y="free sulfur dioxide", data=data);

# %%
#total sulfur dioxide  vs quality
plt.figure(figsize=(5,5))
sns.barplot(x="quality", y="total sulfur dioxide", data=data);

# %%
#density vs quality
plt.figure(figsize=(5,5))
sns.barplot(x="quality", y="density", data=data);

# %%
#pH vs quality
plt.figure(figsize=(5,5))
sns.barplot(x="quality", y="pH", data=data);

# %%
#sulphates vs quality
plt.figure(figsize=(5,5))
sns.barplot(x="quality", y="sulphates", data=data);

# %%
#alcohol vs quality
plt.figure(figsize=(5,5))
sns.barplot(x="quality", y="alcohol", data=data);

# %% [markdown]
# #### Conclusion
# From above visuals we observe that ingredients citric acidity, sulphates and alcohol are the directly proportional to the quality of red wines.
#
# From above visuals we observe that ingredients volatile acidity and chlorides are the inversely proportional to the quality of red wines.

# %% [markdown]
# #### correlation
# 1. positive correlation
#
# 2. negative correlation

# %%
correlation=data.corr()

# %%
#constructing the heatmap to understand the correlation between the columns
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt=".1f", annot=True, annot_kws={"size":8}, cmap="Blues");

# %% [markdown]
# #### Data Preprocessing

# %%
#separate the data and label
X=data.drop("quality", axis=1)
Y=data["quality"]

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
Y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %% [markdown]
# #### label binarization

# %%
Y=data["quality"].apply(lambda y_value: 1 if y_value>=7 else 0)

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: quality, dtype: int64

# %% [markdown]
# #### train_test_split data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=3)
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (1279, 11) (320, 11) (1279,) (320,)

# %% [markdown]
# #### model training : Random Forest Classifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# #### model evaluation using accuracy_score

# %%
#accuracy on train data
X_train_prediction=model.predict(X_train)
train_data_accuracy=accuracy_score(X_train_prediction, Y_train)
print("Accuracy score of the train data is :", train_data_accuracy)
# Out:
# Accuracy score of the train data is : 1.0

# %%
#accuracy on test data
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction, Y_test)
print("Accuracy score of the test data is :", test_data_accuracy)
# Out:
# Accuracy score of the test data is : 0.90625

# %% [markdown]
# #### building a predictive system

# %%
data_in=(7.9,0.43,0.21,1.6,0.106,10.0,37.0,0.9966,3.17,0.91,9.5)

#convert data_in/input data to numpy array
data_in_as_numpy_array=np.asarray(data_in)

#reshape the data as we are predicting the label for only one instance
data_in_reshaped=data_in_as_numpy_array.reshape(1,-1)

prediction=model.predict(data_in_reshaped)

print(prediction)

if (prediction[0]==1):
    print("Good quality wine")
else:
    print("Poor quality wine")
# Out:
# [0]
# Poor quality wine
# C:\Users\Shashi Shekhar\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
